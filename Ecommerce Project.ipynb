# %%
import pandas as pd

# %%
data=pd.read_csv('C:/Users/MAYANK BELE/Downloads/Ecommerce Purchases/Ecommerce Purchases.csv')

# %%
data.describe()
# Out:
#         Credit Card  CC Security Code  Purchase Price
# count  1.000000e+04      10000.000000    10000.000000
# mean   2.341374e+15        907.217800       50.347302
# std    2.256103e+15       1589.693035       29.015836
# min    6.040186e+10          0.000000        0.000000
# 25%    3.056322e+13        280.000000       25.150000
# 50%    8.699942e+14        548.000000       50.505000
# 75%    4.492298e+15        816.000000       75.770000
# max    6.012000e+15       9993.000000       99.990000

# %%
data.head(10)
# Out:
#                                              Address    Lot AM or PM  \
# 0  16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1  9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 2                   Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
# 3              7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 4  23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
# 5  7502 Powell Mission Apt. 768\nTravisland, VA 3...  21 XT       PM
# 6     93971 Conway Causeway\nAndersonburgh, AZ 75107  96 Xt       AM
# 7  260 Rachel Plains Suite 366\nCastroberg, WV 24...  96 pG       PM
# 8            2129 Dylan Burg\nNew Michelle, ME 28650  45 JN       PM
# 9    3795 Dawson Extensions\nLake Tinafort, ID 88739  15 Ug       AM
#
#                                         Browser Info  \
# 0  Opera/9.56.(X11; Linux x86_64; sl-SI) Presto/2...
# 1  Opera/8.93.(Windows 98; Win 9x 4.90; en-US) Pr...
# ...

# %%
data.tail(10)
# Out:
#                                                 Address    Lot AM or PM  \
# 9990  75731 Molly Springs\nWest Danielle, VT 96934-5102  93 ty       PM
# 9991              PSC 8165, Box 8498\nAPO AP 60327-0346  50 dA       AM
# 9992  885 Allen Mountains Apt. 230\nWallhaven, LA 16995  40 vH       PM
# 9993  7555 Larson Locks Suite 229\nEllisburgh, MA 34...  72 jg       PM
# 9994       6276 Rojas Hollow\nLake Louis, WY 56410-7837  93 Ex       PM
# 9995      966 Castaneda Locks\nWest Juliafurt, CO 96415  92 XI       PM
# 9996  832 Curtis Dam Suite 785\nNorth Edwardburgh, T...  41 JY       AM
# 9997              Unit 4434 Box 6343\nDPO AE 28026-0283  74 Zh       AM
# 9998               0096 English Rest\nRoystad, IA 12457  74 cL       PM
# 9999     40674 Barrett Stravenue\nGrimesville, WI 79682  64 Hr       AM
#
#                                            Browser Info  \
# 9990  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_7_4;...
# 9991  Mozilla/5.0 (compatible; MSIE 8.0; Windows NT ...
# ...

# %%
data.dtypes
# Out:
# Address              object
# Lot                  object
# AM or PM             object
# Browser Info         object
# Company              object
# Credit Card           int64
# CC Exp Date          object
# CC Security Code      int64
# CC Provider          object
# Email                object
# Job                  object
# IP Address           object
# Language             object
# Purchase Price      float64
# dtype: object

# %%
import numpy as np

# %%
print(data==np.nan).
# Out:
#       Address    Lot  AM or PM  Browser Info  Company  Credit Card  \
# 0       False  False     False         False    False        False
# 1       False  False     False         False    False        False
# 2       False  False     False         False    False        False
# 3       False  False     False         False    False        False
# 4       False  False     False         False    False        False
# ...       ...    ...       ...           ...      ...          ...
# 9995    False  False     False         False    False        False
# 9996    False  False     False         False    False        False
# 9997    False  False     False         False    False        False
# 9998    False  False     False         False    False        False
# 9999    False  False     False         False    False        False
#
#       CC Exp Date  CC Security Code  CC Provider  Email    Job  IP Address  \
# 0           False             False        False  False  False       False
# ...

# %%
pd.isna(data)
# Out:
#       Address    Lot  AM or PM  Browser Info  Company  Credit Card  \
# 0       False  False     False         False    False        False
# 1       False  False     False         False    False        False
# 2       False  False     False         False    False        False
# 3       False  False     False         False    False        False
# 4       False  False     False         False    False        False
# ...       ...    ...       ...           ...      ...          ...
# 9995    False  False     False         False    False        False
# 9996    False  False     False         False    False        False
# 9997    False  False     False         False    False        False
# 9998    False  False     False         False    False        False
# 9999    False  False     False         False    False        False
#
#       CC Exp Date  CC Security Code  CC Provider  Email    Job  IP Address  \
# 0           False             False        False  False  False       False
# ...

# %%
data.isnull().sum()
# Out:
# Address             0
# Lot                 0
# AM or PM            0
# Browser Info        0
# Company             0
# Credit Card         0
# CC Exp Date         0
# CC Security Code    0
# CC Provider         0
# Email               0
# Job                 0
# IP Address          0
# Language            0
# Purchase Price      0
# dtype: int64

# %%
pd.isna(data).sum()
# Out:
# Address             0
# Lot                 0
# AM or PM            0
# Browser Info        0
# Company             0
# Credit Card         0
# CC Exp Date         0
# CC Security Code    0
# CC Provider         0
# Email               0
# Job                 0
# IP Address          0
# Language            0
# Purchase Price      0
# dtype: int64

# %%
data.shape
# Out:
# (10000, 14)

# %%
data
# Out:
#                                                 Address    Lot AM or PM  \
# 0     16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1     9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 2                      Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
# 3                 7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 4     23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
# ...                                                 ...    ...      ...
# 9995      966 Castaneda Locks\nWest Juliafurt, CO 96415  92 XI       PM
# 9996  832 Curtis Dam Suite 785\nNorth Edwardburgh, T...  41 JY       AM
# 9997              Unit 4434 Box 6343\nDPO AE 28026-0283  74 Zh       AM
# 9998               0096 English Rest\nRoystad, IA 12457  74 cL       PM
# 9999     40674 Barrett Stravenue\nGrimesville, WI 79682  64 Hr       AM
#
#                                            Browser Info  \
# ...

# %%
data.sort_values(by='Purchase Price').head()
# Out:
#                                                 Address    Lot AM or PM  \
# 5487     465 Mallory Ways\nNorth Rebecca, RI 82734-1160  93 OH       PM
# 2876  332 Jones Parkways\nEast Katherineville, GA 64230  39 GT       AM
# 6863     9202 Baker Forks\nNew Chelseaborough, VA 70852  40 Vx       AM
# 8656          146 Laura Mission\nNorth Donald, NC 76608  95 xb       PM
# 2783  402 Joseph Tunnel Apt. 219\nMartinmouth, DE 58480  46 Yg       AM
#
#                                            Browser Info  \
# 5487  Mozilla/5.0 (X11; Linux i686; rv:1.9.6.20) Gec...
# 2876  Mozilla/5.0 (Macintosh; U; PPC Mac OS X 10_6_9...
# 6863  Mozilla/5.0 (iPod; U; CPU iPhone OS 3_3 like M...
# 8656  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_7_2 ...
# 2783  Mozilla/5.0 (Macintosh; U; Intel Mac OS X 10_7...
#
#                     Company       Credit Card CC Exp Date  CC Security Code  \
# 5487         Flynn and Sons    30469912089738       09/23               236
# ...

# %%
data.sort_values(by='Purchase Price').tail()
# Out:
#                                                 Address    Lot AM or PM  \
# 3844  27148 Kathy Cliff Apt. 400\nEast Jillton, TX 5...  37 ou       PM
# 7604            672 James Oval\nNew Davidview, KS 91202  07 dT       PM
# 9856  058 Miranda Locks Suite 792\nPort Davidstad, P...  73 IW       PM
# 7807              PSC 6177, Box 1004\nAPO AA 57143-1269  64 Nf       AM
# 2092          63773 Shelton Greens\nAshleyton, MA 00493  56 lu       AM
#
#                                            Browser Info  \
# 3844  Mozilla/5.0 (compatible; MSIE 9.0; Windows NT ...
# 7604  Mozilla/5.0 (Windows 98; Win 9x 4.90; it-IT; r...
# 9856  Mozilla/5.0 (Windows NT 5.0) AppleWebKit/5360 ...
# 7807  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_5_4)...
# 2092  Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/53...
#
#                         Company       Credit Card CC Exp Date  \
# 3844              King and Sons  3088952915231147       04/17
# 7604          Fitzpatrick Group      503870406017       05/24
# ...

# %%
 data.apply(lambda x: x.max())
# Out:
# Address                              Unit 9991 Box 3616\nDPO AA 99399
# Lot                                                             99 zl
# AM or PM                                                           PM
# Browser Info        Opera/9.99.(X11; Linux x86_64; it-IT) Presto/2...
# Company                                                 Zuniga-Watson
# Credit Card                                          6011999761615928
# CC Exp Date                                                     12/25
# CC Security Code                                                 9993
# CC Provider                                                   Voyager
# Email                                                zyoung@yahoo.com
# Job                                                      Youth worker
# IP Address                                               99.96.230.38
# Language                                                           zh
# ...

# %%
data.apply(lambda y: y.min())
# Out:
# Address             000 Jared Shoals Apt. 244\nRamirezmouth, IL 12450
# Lot                                                             00 AG
# AM or PM                                                           AM
# Browser Info        Mozilla/5.0 (Macintosh; Intel Mac OS X 10_5_0 ...
# Company                                                    Abbott Ltd
# Credit Card                                               60401860543
# CC Exp Date                                                     01/17
# CC Security Code                                                    0
# CC Provider                                          American Express
# Email                                             aabbott@hotmail.com
# Job                                                Academic librarian
# IP Address                                               0.116.212.13
# Language                                                           de
# ...

# %%
data['Purchase Price'].max()
# Out:
# 99.99

# %%
data['Purchase Price'].min()
# Out:
# 0.0

# %%
data['Purchase Price'].mean()
# Out:
# 50.347302

# %%
len(data[data['Language'].isin(['fr'])])
# Out:
# 1097

# %%
len(data[data['Language']=='fr'])
# Out:
# 1097

# %%
data
# Out:
#                                                 Address    Lot AM or PM  \
# 0     16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1     9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 2                      Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
# 3                 7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 4     23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
# ...                                                 ...    ...      ...
# 9995      966 Castaneda Locks\nWest Juliafurt, CO 96415  92 XI       PM
# 9996  832 Curtis Dam Suite 785\nNorth Edwardburgh, T...  41 JY       AM
# 9997              Unit 4434 Box 6343\nDPO AE 28026-0283  74 Zh       AM
# 9998               0096 English Rest\nRoystad, IA 12457  74 cL       PM
# 9999     40674 Barrett Stravenue\nGrimesville, WI 79682  64 Hr       AM
#
#                                            Browser Info  \
# ...

# %%
data[data['Job']=='Drilling engineer']
# Out:
#                                                 Address    Lot AM or PM  \
# 1     9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 3                 7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 779               PSC 9956, Box 2820\nAPO AE 81969-8768  14 yG       PM
# 1104  32038 Adams Valley Suite 436\nNorth Kaylachest...  44 eL       AM
# 1303  98753 Smith Radial Suite 963\nSouth Jasmine, R...  45 cj       AM
# 1531                   PSC 7147, Box 5613\nAPO AE 35453  76 Cs       AM
# 2989  98274 Henderson Expressway Suite 475\nPort Hay...  32 Ls       PM
# 3558  01333 Nicholas Hill Suite 739\nEast Maria, DE ...  45 tj       AM
# 3753  96370 Shannon Isle Apt. 581\nRandallton, PA 62...  05 cD       PM
# 4840  031 Lang Plaza\nLake Matthewchester, NE 79519-...  13 DM       PM
# 4969   5865 Wendy Square\nNew Jacqueline, SD 40769-9181  02 JU       PM
# 4981                   PSC 9130, Box 5382\nAPO AP 58279  36 MU       PM
# ...

# %%
len(data[data['Job'].str.contains('engineer',case=False)])              #case=False makes the string case insensitive
# Out:
# 984

# %%
data
# Out:
#                                                 Address    Lot AM or PM  \
# 0     16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1     9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 2                      Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
# 3                 7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 4     23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
# ...                                                 ...    ...      ...
# 9995      966 Castaneda Locks\nWest Juliafurt, CO 96415  92 XI       PM
# 9996  832 Curtis Dam Suite 785\nNorth Edwardburgh, T...  41 JY       AM
# 9997              Unit 4434 Box 6343\nDPO AE 28026-0283  74 Zh       AM
# 9998               0096 English Rest\nRoystad, IA 12457  74 cL       PM
# 9999     40674 Barrett Stravenue\nGrimesville, WI 79682  64 Hr       AM
#
#                                            Browser Info  \
# ...

# %%
data[data['IP Address']=='132.207.160.22']
# Out:
#                             Address    Lot AM or PM  \
# 2  Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
#
#                                         Browser Info  \
# 2  Mozilla/5.0 (compatible; MSIE 9.0; Windows NT ...
#
#                       Company   Credit Card CC Exp Date  CC Security Code  \
# 2  Simpson, Williams and Pham  675957666125       08/19               699
#
#     CC Provider                           Email                       Job  \
# 2  JCB 16 digit  amymiller@morales-harrison.com  Customer service manager
#
#        IP Address Language  Purchase Price
# 2  132.207.160.22       de            0.95

# %%
data[data['IP Address']=='132.207.160.22']['Email']              #diplays EMAIL of given IP address
# Out:
# 2    amymiller@morales-harrison.com
# Name: Email, dtype: object

# %%
data
# Out:
#                                                 Address    Lot AM or PM  \
# 0     16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1     9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 2                      Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
# 3                 7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 4     23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
# ...                                                 ...    ...      ...
# 9995      966 Castaneda Locks\nWest Juliafurt, CO 96415  92 XI       PM
# 9996  832 Curtis Dam Suite 785\nNorth Edwardburgh, T...  41 JY       AM
# 9997              Unit 4434 Box 6343\nDPO AE 28026-0283  74 Zh       AM
# 9998               0096 English Rest\nRoystad, IA 12457  74 cL       PM
# 9999     40674 Barrett Stravenue\nGrimesville, WI 79682  64 Hr       AM
#
#                                            Browser Info  \
# ...

# %%
data[data['CC Provider']=='Mastercard']
# Out:
#                                                 Address    Lot AM or PM  \
# 1     9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 18    461 Christopher Square\nWest Michaelchester, C...  17 SB       PM
# 31                     USNS Alvarado\nFPO AA 27052-1231  26 Lh       PM
# 35    93392 Webb Gardens Apt. 220\nLaurabury, AR 999...  37 om       AM
# 41    779 Sydney Keys Apt. 119\nAnthonyside, NH 2179...  21 lh       PM
# ...                                                 ...    ...      ...
# 9947      32827 Carl Inlet\nSouth Nicole, NY 38081-6636  40 Dp       PM
# 9948  95544 Johnson Isle Suite 939\nMichaelberg, RI ...  91 bW       AM
# 9954  051 Samantha Wells Apt. 328\nScottborough, OR ...  11 vG       AM
# 9981  087 Larson Roads Apt. 587\nRicestad, WI 98077-...  95 Kw       AM
# 9987     2754 Klein Mission\nJohnsonview, PA 64925-9624  65 Fg       PM
#
#                                            Browser Info  \
# ...

# %%
master=data[data['CC Provider'].str.contains('Mastercard',case=False)]
master[master['Purchase Price']>50]
# Out:
#                                                 Address    Lot AM or PM  \
# 1     9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 18    461 Christopher Square\nWest Michaelchester, C...  17 SB       PM
# 31                     USNS Alvarado\nFPO AA 27052-1231  26 Lh       PM
# 35    93392 Webb Gardens Apt. 220\nLaurabury, AR 999...  37 om       AM
# 90          431 Bowen Lights\nFergusonborough, MH 01362  31 tG       AM
# ...                                                 ...    ...      ...
# 9941           43757 Brown Lodge\nValerieberg, PR 88518  68 DG       AM
# 9948  95544 Johnson Isle Suite 939\nMichaelberg, RI ...  91 bW       AM
# 9954  051 Samantha Wells Apt. 328\nScottborough, OR ...  11 vG       AM
# 9981  087 Larson Roads Apt. 587\nRicestad, WI 98077-...  95 Kw       AM
# 9987     2754 Klein Mission\nJohnsonview, PA 64925-9624  65 Fg       PM
#
#                                            Browser Info  \
# ...

# %%
len(data[(data['CC Provider']=='Mastercard')& (data['Purchase Price']>50)])
# Out:
# 405

# %%
data[(data['CC Provider']=='Mastercard')& (data['Purchase Price']>50)]
# Out:
#                                                 Address    Lot AM or PM  \
# 1     9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 18    461 Christopher Square\nWest Michaelchester, C...  17 SB       PM
# 31                     USNS Alvarado\nFPO AA 27052-1231  26 Lh       PM
# 35    93392 Webb Gardens Apt. 220\nLaurabury, AR 999...  37 om       AM
# 90          431 Bowen Lights\nFergusonborough, MH 01362  31 tG       AM
# ...                                                 ...    ...      ...
# 9941           43757 Brown Lodge\nValerieberg, PR 88518  68 DG       AM
# 9948  95544 Johnson Isle Suite 939\nMichaelberg, RI ...  91 bW       AM
# 9954  051 Samantha Wells Apt. 328\nScottborough, OR ...  11 vG       AM
# 9981  087 Larson Roads Apt. 587\nRicestad, WI 98077-...  95 Kw       AM
# 9987     2754 Klein Mission\nJohnsonview, PA 64925-9624  65 Fg       PM
#
#                                            Browser Info  \
# ...

# %%
data
# Out:
#                                                 Address    Lot AM or PM  \
# 0     16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1     9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 2                      Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
# 3                 7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 4     23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
# ...                                                 ...    ...      ...
# 9995      966 Castaneda Locks\nWest Juliafurt, CO 96415  92 XI       PM
# 9996  832 Curtis Dam Suite 785\nNorth Edwardburgh, T...  41 JY       AM
# 9997              Unit 4434 Box 6343\nDPO AE 28026-0283  74 Zh       AM
# 9998               0096 English Rest\nRoystad, IA 12457  74 cL       PM
# 9999     40674 Barrett Stravenue\nGrimesville, WI 79682  64 Hr       AM
#
#                                            Browser Info  \
# ...

# %%
data[data['Credit Card']==int(180003348082930)]['Email']
# Out:
# 9998    elizabethmoore@reid.net
# Name: Email, dtype: object

# %%
data.dtypes
# Out:
# Address              object
# Lot                  object
# AM or PM             object
# Browser Info         object
# Company              object
# Credit Card           int64
# CC Exp Date          object
# CC Security Code      int64
# CC Provider          object
# Email                object
# Job                  object
# IP Address           object
# Language             object
# Purchase Price      float64
# dtype: object

# %%
len(data[data['AM or PM']=='PM'])
# Out:
# 5068

# %%
len(data[data['AM or PM']=='AM'])
# Out:
# 4932

# %%
len(data[data['CC Exp Date'].str.contains('/20')])
# Out:
# 988

# %%
def fun():
    count=0
    for date in data['CC Exp Date']:
        if date.split('/')[1]=='20':
            count=count+1
    return count

# %%
fun()
# Out:
# 988

# %%
len(data[data['CC Exp Date'].apply(lambda x:x[3:]=='20')])
# Out:
# 988

# %%
toppp=pd.DataFrame(data['Email'].apply(lambda x: x.split('@')[1]))

# %%
fr=toppp.groupby('Email').size()

# %%
fr.sort_values().tail()                      #could hav ealso done using toppp.groupby('Email').size().sort_values().tail()
# Out:
# Email
# williams.com      37
# smith.com         42
# gmail.com       1605
# yahoo.com       1616
# hotmail.com     1638
# dtype: int64

# %%
pd.DataFrame(data['Email'].apply(lambda x: x.split('@')[1])).groupby('Email').size().sort_values().tail()
# Out:
# Email
# williams.com      37
# smith.com         42
# gmail.com       1605
# yahoo.com       1616
# hotmail.com     1638
# dtype: int64

# %%
toppp.groupby('Email').size().sort_values().tail()
# Out:
# Email
# williams.com      37
# smith.com         42
# gmail.com       1605
# yahoo.com       1616
# hotmail.com     1638
# dtype: int64
